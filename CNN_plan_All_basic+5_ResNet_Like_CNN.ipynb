# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.python.client import device_lib
from tensorflow.keras.optimizers import schedules
from tensorflow.keras.callbacks import ModelCheckpoint

import pickle
import math
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import sklearn
from sklearn import linear_model
from sklearn import metrics
from sklearn import model_selection
from scipy.optimize import minimize

# %%
# BasicCNN
# 284,947 params
def getModel0():
  opt = tf.keras.optimizers.Adam()

  model = keras.Sequential()
  model.add(keras.layers.Conv1D(64, 192, kernel_initializer='normal', activation='relu', input_shape=(1500, 1)))
  model.add(keras.layers.BatchNormalization())
  model.add(keras.layers.MaxPooling1D(5))
  model.add(keras.layers.Dropout(0.5))
  model.add(keras.layers.Conv1D(48, 64, kernel_initializer='normal', activation='relu'))
  model.add(keras.layers.BatchNormalization())
  model.add(keras.layers.MaxPooling1D(5))
  model.add(keras.layers.Dropout(0.5))
  model.add(keras.layers.Conv1D(32, 18, kernel_initializer='normal', activation='relu'))
  model.add(keras.layers.BatchNormalization())
  model.add(keras.layers.Dropout(0.5))
  model.add(keras.layers.Flatten())
  model.add(keras.layers.Dense(64, kernel_initializer='normal', activation='relu'))
  model.add(keras.layers.BatchNormalization())
  model.add(keras.layers.Dropout(0.5))
  model.add(keras.layers.Dense(32, kernel_initializer='normal', activation='relu'))
  model.add(keras.layers.BatchNormalization())
  model.add(keras.layers.Dense(3, kernel_initializer='normal', activation='softmax'))
  model.compile(loss='categorical_crossentropy', optimizer=opt, metrics=['accuracy'])

  return model

model = getModel0()
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_205 (Conv1D)         (None, 1309, 64)          12352
#
#  batch_normalization_228 (Ba  (None, 1309, 64)         256
#  tchNormalization)
#
#  max_pooling1d_56 (MaxPoolin  (None, 261, 64)          0
#  g1D)
#
#  dropout_90 (Dropout)        (None, 261, 64)           0
#
#  conv1d_206 (Conv1D)         (None, 198, 48)           196656
#
#  batch_normalization_229 (Ba  (None, 198, 48)          192
#  tchNormalization)
#
#  max_pooling1d_57 (MaxPoolin  (None, 39, 48)           0
#  g1D)
#
#  dropout_91 (Dropout)        (None, 39, 48)            0
#
#  conv1d_207 (Conv1D)         (None, 22, 32)            27680
#
#  batch_normalization_230 (Ba  (None, 22, 32)           128
#  tchNormalization)
#
#  dropout_92 (Dropout)        (None, 22, 32)            0
#
#  flatten_17 (Flatten)        (None, 704)               0
#
#  dense_40 (Dense)            (None, 64)                45120
#
#  batch_normalization_231 (Ba  (None, 64)               256
#  tchNormalization)
#
#  dropout_93 (Dropout)        (None, 64)                0
#
#  dense_41 (Dense)            (None, 32)                2080
#
#  batch_normalization_232 (Ba  (None, 32)               128
#  tchNormalization)
#
#  dense_42 (Dense)            (None, 3)                 99
#
# =================================================================
# Total params: 284,947
# Trainable params: 284,467
# Non-trainable params: 480
# _________________________________________________________________

# %%
# ResNetLikeCNNx3
# 344,259 params
def getModel1():
  opt = tf.keras.optimizers.Adam()
  inputs = tf.keras.Input(shape=(1500, 1))

  x = tf.keras.layers.Conv1D(64, 192, activation='relu')(inputs)
  x = tf.keras.layers.BatchNormalization()(x)
  x = tf.keras.layers.MaxPooling1D(7)(x)
  x = tf.keras.layers.Dropout(0.5)(x)

  # Residual block 1
  shortcut = tf.keras.layers.Conv1D(48, 1)(x)
  shortcut = tf.keras.layers.BatchNormalization()(shortcut)

  x = tf.keras.layers.Conv1D(48, 32, padding='same', activation='relu')(x)
  x = tf.keras.layers.BatchNormalization()(x)
  x = tf.keras.layers.Conv1D(48, 32, padding='same', activation='relu')(x)
  x = tf.keras.layers.BatchNormalization()(x)
  x = tf.keras.layers.Conv1D(48, 32, padding='same', activation='relu')(x)
  x = tf.keras.layers.BatchNormalization()(x)

  x = tf.keras.layers.Add()([x, shortcut])

  x = tf.keras.layers.MaxPooling1D(5)(x)
  x = tf.keras.layers.Dropout(0.5)(x)

  # Residual block 2
  shortcut = tf.keras.layers.Conv1D(24, 1)(x)
  shortcut = tf.keras.layers.BatchNormalization()(shortcut)

  x = tf.keras.layers.Conv1D(24, 16, padding='same', activation='relu')(x)
  x = tf.keras.layers.BatchNormalization()(x)
  x = tf.keras.layers.Conv1D(24, 16, padding='same', activation='relu')(x)
  x = tf.keras.layers.BatchNormalization()(x)
  x = tf.keras.layers.Conv1D(24, 16, padding='same', activation='relu')(x)
  x = tf.keras.layers.BatchNormalization()(x)

  x = tf.keras.layers.Add()([x, shortcut])

  x = tf.keras.layers.Flatten()(x)
  x = tf.keras.layers.Dropout(0.5)(x)
  x = tf.keras.layers.Dense(48, activation='relu')(x)
  x = tf.keras.layers.BatchNormalization()(x)
  x = tf.keras.layers.Dropout(0.5)(x)
  x = tf.keras.layers.Dense(24, activation='relu')(x)
  x = tf.keras.layers.BatchNormalization()(x)

  outputs = tf.keras.layers.Dense(3, activation='softmax')(x)

  model = tf.keras.Model(inputs=inputs, outputs=outputs)

  model.compile(loss='categorical_crossentropy', optimizer=opt, metrics=['accuracy'])

  return model

model = getModel1()
model.summary()
# Out:
# Model: "model_14"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_15 (InputLayer)          [(None, 1500, 1)]    0           []
#
#  conv1d_196 (Conv1D)            (None, 1309, 64)     12352       ['input_15[0][0]']
#
#  batch_normalization_217 (Batch  (None, 1309, 64)    256         ['conv1d_196[0][0]']
#  Normalization)
#
#  max_pooling1d_54 (MaxPooling1D  (None, 187, 64)     0           ['batch_normalization_217[0][0]']
#  )
#
#  dropout_86 (Dropout)           (None, 187, 64)      0           ['max_pooling1d_54[0][0]']
#
#  conv1d_198 (Conv1D)            (None, 187, 48)      98352       ['dropout_86[0][0]']
#
#  batch_normalization_219 (Batch  (None, 187, 48)     192         ['conv1d_198[0][0]']
#  Normalization)
#
#  conv1d_199 (Conv1D)            (None, 187, 48)      73776       ['batch_normalization_219[0][0]']
#
#  batch_normalization_220 (Batch  (None, 187, 48)     192         ['conv1d_199[0][0]']
#  Normalization)
#
#  conv1d_200 (Conv1D)            (None, 187, 48)      73776       ['batch_normalization_220[0][0]']
#
#  conv1d_197 (Conv1D)            (None, 187, 48)      3120        ['dropout_86[0][0]']
#
#  batch_normalization_221 (Batch  (None, 187, 48)     192         ['conv1d_200[0][0]']
#  Normalization)
#
#  batch_normalization_218 (Batch  (None, 187, 48)     192         ['conv1d_197[0][0]']
#  Normalization)
#
#  add_49 (Add)                   (None, 187, 48)      0           ['batch_normalization_221[0][0]',
#                                                                   'batch_normalization_218[0][0]']
#
#  max_pooling1d_55 (MaxPooling1D  (None, 37, 48)      0           ['add_49[0][0]']
#  )
#
#  dropout_87 (Dropout)           (None, 37, 48)       0           ['max_pooling1d_55[0][0]']
#
#  conv1d_202 (Conv1D)            (None, 37, 24)       18456       ['dropout_87[0][0]']
#
#  batch_normalization_223 (Batch  (None, 37, 24)      96          ['conv1d_202[0][0]']
#  Normalization)
#
#  conv1d_203 (Conv1D)            (None, 37, 24)       9240        ['batch_normalization_223[0][0]']
#
#  batch_normalization_224 (Batch  (None, 37, 24)      96          ['conv1d_203[0][0]']
#  Normalization)
#
#  conv1d_204 (Conv1D)            (None, 37, 24)       9240        ['batch_normalization_224[0][0]']
#
#  conv1d_201 (Conv1D)            (None, 37, 24)       1176        ['dropout_87[0][0]']
#
#  batch_normalization_225 (Batch  (None, 37, 24)      96          ['conv1d_204[0][0]']
#  Normalization)
#
#  batch_normalization_222 (Batch  (None, 37, 24)      96          ['conv1d_201[0][0]']
#  Normalization)
#
#  add_50 (Add)                   (None, 37, 24)       0           ['batch_normalization_225[0][0]',
#                                                                   'batch_normalization_222[0][0]']
#
#  flatten_16 (Flatten)           (None, 888)          0           ['add_50[0][0]']
#
#  dropout_88 (Dropout)           (None, 888)          0           ['flatten_16[0][0]']
#
#  dense_37 (Dense)               (None, 48)           42672       ['dropout_88[0][0]']
#
#  batch_normalization_226 (Batch  (None, 48)          192         ['dense_37[0][0]']
#  Normalization)
#
#  dropout_89 (Dropout)           (None, 48)           0           ['batch_normalization_226[0][0]']
#
#  dense_38 (Dense)               (None, 24)           1176        ['dropout_89[0][0]']
#
#  batch_normalization_227 (Batch  (None, 24)          96          ['dense_38[0][0]']
#  Normalization)
#
#  dense_39 (Dense)               (None, 3)            75          ['batch_normalization_227[0][0]']
#
# ==================================================================================================
# Total params: 345,107
# Trainable params: 344,259
# Non-trainable params: 848
# __________________________________________________________________________________________________

# %%
# ResNetLikeCNNx4
# 309,051 params
def getModel2():
  opt = tf.keras.optimizers.Adam()
  inputs = tf.keras.Input(shape=(1500, 1))

  x = tf.keras.layers.Conv1D(64, 192, activation='relu')(inputs)
  x = tf.keras.layers.BatchNormalization()(x)
  x = tf.keras.layers.MaxPooling1D(7)(x)
  x = tf.keras.layers.Dropout(0.5)(x)

  # Residual block 1
  shortcut = tf.keras.layers.Conv1D(48, 1)(x)
  shortcut = tf.keras.layers.BatchNormalization()(shortcut)

  x = tf.keras.layers.Conv1D(96, 1, padding='same', activation='relu')(x)
  x = tf.keras.layers.BatchNormalization()(x)
  x = tf.keras.layers.Conv1D(96, 9, padding='same', activation='relu')(x)
  x = tf.keras.layers.BatchNormalization()(x)
  x = tf.keras.layers.Conv1D(96, 9, padding='same', activation='relu')(x)
  x = tf.keras.layers.BatchNormalization()(x)
  x = tf.keras.layers.Conv1D(48, 3, padding='same', activation='relu')(x)
  x = tf.keras.layers.BatchNormalization()(x)

  x = tf.keras.layers.Add()([x, shortcut])

  x = tf.keras.layers.MaxPooling1D(5)(x)
  x = tf.keras.layers.Dropout(0.5)(x)

  # Residual block 2
  shortcut = tf.keras.layers.Conv1D(24, 1)(x)
  shortcut = tf.keras.layers.BatchNormalization()(shortcut)

  x = tf.keras.layers.Conv1D(72, 1, padding='same', activation='relu')(x)
  x = tf.keras.layers.BatchNormalization()(x)
  x = tf.keras.layers.Conv1D(72, 5, padding='same', activation='relu')(x)
  x = tf.keras.layers.BatchNormalization()(x)
  x = tf.keras.layers.Conv1D(72, 5, padding='same', activation='relu')(x)
  x = tf.keras.layers.BatchNormalization()(x)
  x = tf.keras.layers.Conv1D(24, 3, padding='same', activation='relu')(x)
  x = tf.keras.layers.BatchNormalization()(x)

  x = tf.keras.layers.Add()([x, shortcut])

  x = tf.keras.layers.Flatten()(x)
  x = tf.keras.layers.Dropout(0.5)(x)
  x = tf.keras.layers.Dense(48, activation='relu')(x)
  x = tf.keras.layers.BatchNormalization()(x)
  x = tf.keras.layers.Dropout(0.5)(x)
  x = tf.keras.layers.Dense(24, activation='relu')(x)
  x = tf.keras.layers.BatchNormalization()(x)

  outputs = tf.keras.layers.Dense(3, activation='softmax')(x)

  model = tf.keras.Model(inputs=inputs, outputs=outputs)

  model.compile(loss='categorical_crossentropy', optimizer=opt, metrics=['accuracy'])

  return model

model = getModel2()
model.summary()
# Out:
# Model: "model_13"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_14 (InputLayer)          [(None, 1500, 1)]    0           []
#
#  conv1d_185 (Conv1D)            (None, 1309, 64)     12352       ['input_14[0][0]']
#
#  batch_normalization_204 (Batch  (None, 1309, 64)    256         ['conv1d_185[0][0]']
#  Normalization)
#
#  max_pooling1d_52 (MaxPooling1D  (None, 187, 64)     0           ['batch_normalization_204[0][0]']
#  )
#
#  dropout_82 (Dropout)           (None, 187, 64)      0           ['max_pooling1d_52[0][0]']
#
#  conv1d_187 (Conv1D)            (None, 187, 96)      6240        ['dropout_82[0][0]']
#
#  batch_normalization_206 (Batch  (None, 187, 96)     384         ['conv1d_187[0][0]']
#  Normalization)
#
#  conv1d_188 (Conv1D)            (None, 187, 96)      83040       ['batch_normalization_206[0][0]']
#
#  batch_normalization_207 (Batch  (None, 187, 96)     384         ['conv1d_188[0][0]']
#  Normalization)
#
#  conv1d_189 (Conv1D)            (None, 187, 96)      83040       ['batch_normalization_207[0][0]']
#
#  batch_normalization_208 (Batch  (None, 187, 96)     384         ['conv1d_189[0][0]']
#  Normalization)
#
#  conv1d_190 (Conv1D)            (None, 187, 48)      13872       ['batch_normalization_208[0][0]']
#
#  conv1d_186 (Conv1D)            (None, 187, 48)      3120        ['dropout_82[0][0]']
#
#  batch_normalization_209 (Batch  (None, 187, 48)     192         ['conv1d_190[0][0]']
#  Normalization)
#
#  batch_normalization_205 (Batch  (None, 187, 48)     192         ['conv1d_186[0][0]']
#  Normalization)
#
#  add_47 (Add)                   (None, 187, 48)      0           ['batch_normalization_209[0][0]',
#                                                                   'batch_normalization_205[0][0]']
#
#  max_pooling1d_53 (MaxPooling1D  (None, 37, 48)      0           ['add_47[0][0]']
#  )
#
#  dropout_83 (Dropout)           (None, 37, 48)       0           ['max_pooling1d_53[0][0]']
#
#  conv1d_192 (Conv1D)            (None, 37, 72)       3528        ['dropout_83[0][0]']
#
#  batch_normalization_211 (Batch  (None, 37, 72)      288         ['conv1d_192[0][0]']
#  Normalization)
#
#  conv1d_193 (Conv1D)            (None, 37, 72)       25992       ['batch_normalization_211[0][0]']
#
#  batch_normalization_212 (Batch  (None, 37, 72)      288         ['conv1d_193[0][0]']
#  Normalization)
#
#  conv1d_194 (Conv1D)            (None, 37, 72)       25992       ['batch_normalization_212[0][0]']
#
#  batch_normalization_213 (Batch  (None, 37, 72)      288         ['conv1d_194[0][0]']
#  Normalization)
#
#  conv1d_195 (Conv1D)            (None, 37, 24)       5208        ['batch_normalization_213[0][0]']
#
#  conv1d_191 (Conv1D)            (None, 37, 24)       1176        ['dropout_83[0][0]']
#
#  batch_normalization_214 (Batch  (None, 37, 24)      96          ['conv1d_195[0][0]']
#  Normalization)
#
#  batch_normalization_210 (Batch  (None, 37, 24)      96          ['conv1d_191[0][0]']
#  Normalization)
#
#  add_48 (Add)                   (None, 37, 24)       0           ['batch_normalization_214[0][0]',
#                                                                   'batch_normalization_210[0][0]']
#
#  flatten_15 (Flatten)           (None, 888)          0           ['add_48[0][0]']
#
#  dropout_84 (Dropout)           (None, 888)          0           ['flatten_15[0][0]']
#
#  dense_34 (Dense)               (None, 48)           42672       ['dropout_84[0][0]']
#
#  batch_normalization_215 (Batch  (None, 48)          192         ['dense_34[0][0]']
#  Normalization)
#
#  dropout_85 (Dropout)           (None, 48)           0           ['batch_normalization_215[0][0]']
#
#  dense_35 (Dense)               (None, 24)           1176        ['dropout_85[0][0]']
#
#  batch_normalization_216 (Batch  (None, 24)          96          ['dense_35[0][0]']
#  Normalization)
#
#  dense_36 (Dense)               (None, 3)            75          ['batch_normalization_216[0][0]']
#
# ==================================================================================================
# Total params: 310,619
# Trainable params: 309,051
# Non-trainable params: 1,568
# __________________________________________________________________________________________________

# %%
# SmallerResNet4x2
# 147,811 params
def getModel3():
  opt = tf.keras.optimizers.Adam()
  inputs = tf.keras.Input(shape=(1500, 1))

  x = tf.keras.layers.Conv1D(32, 15, padding='same', activation='relu')(inputs)
  x = tf.keras.layers.BatchNormalization()(x)
  x = tf.keras.layers.MaxPooling1D(5)(x)
  x = tf.keras.layers.Dropout(0.5)(x)

  # Residual block 1
  shortcut = tf.keras.layers.Conv1D(48, 1)(x)
  shortcut = tf.keras.layers.BatchNormalization()(shortcut)

  x = tf.keras.layers.Conv1D(48, 5, padding='same', activation='relu')(x)
  x = tf.keras.layers.BatchNormalization()(x)
  x = tf.keras.layers.Conv1D(48, 5, padding='same', activation='relu')(x)
  x = tf.keras.layers.BatchNormalization()(x)
  x = tf.keras.layers.Add()([x, shortcut])

  x = tf.keras.layers.MaxPooling1D(3)(x)
  x = tf.keras.layers.Dropout(0.5)(x)

  # Residual block 2
  shortcut = tf.keras.layers.Conv1D(56, 1)(x)
  shortcut = tf.keras.layers.BatchNormalization()(shortcut)

  x = tf.keras.layers.Conv1D(56, 5, padding='same', activation='relu')(x)
  x = tf.keras.layers.BatchNormalization()(x)
  x = tf.keras.layers.Conv1D(56, 5, padding='same', activation='relu')(x)
  x = tf.keras.layers.BatchNormalization()(x)
  x = tf.keras.layers.Add()([x, shortcut])

  x = tf.keras.layers.MaxPooling1D(3)(x)
  x = tf.keras.layers.Dropout(0.5)(x)

  # Residual block 3
  shortcut = tf.keras.layers.Conv1D(64, 1)(x)
  shortcut = tf.keras.layers.BatchNormalization()(shortcut)

  x = tf.keras.layers.Conv1D(64, 3, padding='same', activation='relu')(x)
  x = tf.keras.layers.BatchNormalization()(x)
  x = tf.keras.layers.Conv1D(64, 3, padding='same', activation='relu')(x)
  x = tf.keras.layers.BatchNormalization()(x)
  x = tf.keras.layers.Add()([x, shortcut])

  x = tf.keras.layers.MaxPooling1D(3)(x)
  x = tf.keras.layers.Dropout(0.5)(x)

  # Residual block 4
  shortcut = tf.keras.layers.Conv1D(72, 1)(x)
  shortcut = tf.keras.layers.BatchNormalization()(shortcut)

  x = tf.keras.layers.Conv1D(72, 3, padding='same', activation='relu')(x)
  x = tf.keras.layers.BatchNormalization()(x)
  x = tf.keras.layers.Conv1D(72, 3, padding='same', activation='relu')(x)
  x = tf.keras.layers.BatchNormalization()(x)
  x = tf.keras.layers.Add()([x, shortcut])

  x = tf.keras.layers.Dropout(0.5)(x)

  x = tf.keras.layers.Flatten()(x)
  x = tf.keras.layers.Dropout(0.5)(x)
  x = tf.keras.layers.Dense(40, activation='relu')(x)
  x = tf.keras.layers.BatchNormalization()(x)

  outputs = tf.keras.layers.Dense(3, activation='softmax')(x)

  model = tf.keras.Model(inputs=inputs, outputs=outputs)

  model.compile(loss='categorical_crossentropy', optimizer=opt, metrics=['accuracy'])

  return model

model = getModel3()
model.summary()
# Out:
# Model: "model_12"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_13 (InputLayer)          [(None, 1500, 1)]    0           []
#
#  conv1d_172 (Conv1D)            (None, 1500, 32)     512         ['input_13[0][0]']
#
#  batch_normalization_190 (Batch  (None, 1500, 32)    128         ['conv1d_172[0][0]']
#  Normalization)
#
#  max_pooling1d_48 (MaxPooling1D  (None, 300, 32)     0           ['batch_normalization_190[0][0]']
#  )
#
#  dropout_76 (Dropout)           (None, 300, 32)      0           ['max_pooling1d_48[0][0]']
#
#  conv1d_174 (Conv1D)            (None, 300, 48)      7728        ['dropout_76[0][0]']
#
#  batch_normalization_192 (Batch  (None, 300, 48)     192         ['conv1d_174[0][0]']
#  Normalization)
#
#  conv1d_175 (Conv1D)            (None, 300, 48)      11568       ['batch_normalization_192[0][0]']
#
#  conv1d_173 (Conv1D)            (None, 300, 48)      1584        ['dropout_76[0][0]']
#
#  batch_normalization_193 (Batch  (None, 300, 48)     192         ['conv1d_175[0][0]']
#  Normalization)
#
#  batch_normalization_191 (Batch  (None, 300, 48)     192         ['conv1d_173[0][0]']
#  Normalization)
#
#  add_43 (Add)                   (None, 300, 48)      0           ['batch_normalization_193[0][0]',
#                                                                   'batch_normalization_191[0][0]']
#
#  max_pooling1d_49 (MaxPooling1D  (None, 100, 48)     0           ['add_43[0][0]']
#  )
#
#  dropout_77 (Dropout)           (None, 100, 48)      0           ['max_pooling1d_49[0][0]']
#
#  conv1d_177 (Conv1D)            (None, 100, 56)      13496       ['dropout_77[0][0]']
#
#  batch_normalization_195 (Batch  (None, 100, 56)     224         ['conv1d_177[0][0]']
#  Normalization)
#
#  conv1d_178 (Conv1D)            (None, 100, 56)      15736       ['batch_normalization_195[0][0]']
#
#  conv1d_176 (Conv1D)            (None, 100, 56)      2744        ['dropout_77[0][0]']
#
#  batch_normalization_196 (Batch  (None, 100, 56)     224         ['conv1d_178[0][0]']
#  Normalization)
#
#  batch_normalization_194 (Batch  (None, 100, 56)     224         ['conv1d_176[0][0]']
#  Normalization)
#
#  add_44 (Add)                   (None, 100, 56)      0           ['batch_normalization_196[0][0]',
#                                                                   'batch_normalization_194[0][0]']
#
#  max_pooling1d_50 (MaxPooling1D  (None, 33, 56)      0           ['add_44[0][0]']
#  )
#
#  dropout_78 (Dropout)           (None, 33, 56)       0           ['max_pooling1d_50[0][0]']
#
#  conv1d_180 (Conv1D)            (None, 33, 64)       10816       ['dropout_78[0][0]']
#
#  batch_normalization_198 (Batch  (None, 33, 64)      256         ['conv1d_180[0][0]']
#  Normalization)
#
#  conv1d_181 (Conv1D)            (None, 33, 64)       12352       ['batch_normalization_198[0][0]']
#
#  conv1d_179 (Conv1D)            (None, 33, 64)       3648        ['dropout_78[0][0]']
#
#  batch_normalization_199 (Batch  (None, 33, 64)      256         ['conv1d_181[0][0]']
#  Normalization)
#
#  batch_normalization_197 (Batch  (None, 33, 64)      256         ['conv1d_179[0][0]']
#  Normalization)
#
#  add_45 (Add)                   (None, 33, 64)       0           ['batch_normalization_199[0][0]',
#                                                                   'batch_normalization_197[0][0]']
#
#  max_pooling1d_51 (MaxPooling1D  (None, 11, 64)      0           ['add_45[0][0]']
#  )
#
#  dropout_79 (Dropout)           (None, 11, 64)       0           ['max_pooling1d_51[0][0]']
#
#  conv1d_183 (Conv1D)            (None, 11, 72)       13896       ['dropout_79[0][0]']
#
#  batch_normalization_201 (Batch  (None, 11, 72)      288         ['conv1d_183[0][0]']
#  Normalization)
#
#  conv1d_184 (Conv1D)            (None, 11, 72)       15624       ['batch_normalization_201[0][0]']
#
#  conv1d_182 (Conv1D)            (None, 11, 72)       4680        ['dropout_79[0][0]']
#
#  batch_normalization_202 (Batch  (None, 11, 72)      288         ['conv1d_184[0][0]']
#  Normalization)
#
#  batch_normalization_200 (Batch  (None, 11, 72)      288         ['conv1d_182[0][0]']
#  Normalization)
#
#  add_46 (Add)                   (None, 11, 72)       0           ['batch_normalization_202[0][0]',
#                                                                   'batch_normalization_200[0][0]']
#
#  dropout_80 (Dropout)           (None, 11, 72)       0           ['add_46[0][0]']
#
#  flatten_14 (Flatten)           (None, 792)          0           ['dropout_80[0][0]']
#
#  dropout_81 (Dropout)           (None, 792)          0           ['flatten_14[0][0]']
#
#  dense_32 (Dense)               (None, 40)           31720       ['dropout_81[0][0]']
#
#  batch_normalization_203 (Batch  (None, 40)          160         ['dense_32[0][0]']
#  Normalization)
#
#  dense_33 (Dense)               (None, 3)            123         ['batch_normalization_203[0][0]']
#
# ==================================================================================================
# Total params: 149,395
# Trainable params: 147,811
# Non-trainable params: 1,584
# __________________________________________________________________________________________________

# %%
# SmallerResNet4x3
# 151,451 params
def getModel4():
  opt = tf.keras.optimizers.Adam()
  inputs = tf.keras.Input(shape=(1500, 1))

  x = tf.keras.layers.Conv1D(32, 15, padding='same', activation='relu')(inputs)
  x = tf.keras.layers.BatchNormalization()(x)
  x = tf.keras.layers.MaxPooling1D(5)(x)
  x = tf.keras.layers.Dropout(0.5)(x)

  # Residual block 1
  shortcut = tf.keras.layers.Conv1D(40, 1)(x)
  shortcut = tf.keras.layers.BatchNormalization()(shortcut)

  x = tf.keras.layers.Conv1D(48, 1, padding='same', activation='relu')(x)
  x = tf.keras.layers.BatchNormalization()(x)
  x = tf.keras.layers.Conv1D(48, 5, padding='same', activation='relu')(x)
  x = tf.keras.layers.BatchNormalization()(x)
  x = tf.keras.layers.Conv1D(40, 1, padding='same', activation='relu')(x)
  x = tf.keras.layers.BatchNormalization()(x)
  x = tf.keras.layers.Add()([x, shortcut])

  x = tf.keras.layers.MaxPooling1D(3)(x)
  x = tf.keras.layers.Dropout(0.5)(x)

  # Residual block 2
  shortcut = tf.keras.layers.Conv1D(48, 1)(x)
  shortcut = tf.keras.layers.BatchNormalization()(shortcut)

  x = tf.keras.layers.Conv1D(64, 1, padding='same', activation='relu')(x)
  x = tf.keras.layers.BatchNormalization()(x)
  x = tf.keras.layers.Conv1D(64, 5, padding='same', activation='relu')(x)
  x = tf.keras.layers.BatchNormalization()(x)
  x = tf.keras.layers.Conv1D(48, 1, padding='same', activation='relu')(x)
  x = tf.keras.layers.BatchNormalization()(x)
  x = tf.keras.layers.Add()([x, shortcut])

  x = tf.keras.layers.MaxPooling1D(3)(x)
  x = tf.keras.layers.Dropout(0.5)(x)

  # Residual block 3
  shortcut = tf.keras.layers.Conv1D(56, 1)(x)
  shortcut = tf.keras.layers.BatchNormalization()(shortcut)

  x = tf.keras.layers.Conv1D(74, 1, padding='same', activation='relu')(x)
  x = tf.keras.layers.BatchNormalization()(x)
  x = tf.keras.layers.Conv1D(74, 3, padding='same', activation='relu')(x)
  x = tf.keras.layers.BatchNormalization()(x)
  x = tf.keras.layers.Conv1D(56, 1, padding='same', activation='relu')(x)
  x = tf.keras.layers.BatchNormalization()(x)
  x = tf.keras.layers.Add()([x, shortcut])

  x = tf.keras.layers.MaxPooling1D(3)(x)
  x = tf.keras.layers.Dropout(0.5)(x)

  # Residual block 4
  shortcut = tf.keras.layers.Conv1D(64, 1)(x)
  shortcut = tf.keras.layers.BatchNormalization()(shortcut)

  x = tf.keras.layers.Conv1D(96, 1, padding='same', activation='relu')(x)
  x = tf.keras.layers.BatchNormalization()(x)
  x = tf.keras.layers.Conv1D(96, 3, padding='same', activation='relu')(x)
  x = tf.keras.layers.BatchNormalization()(x)
  x = tf.keras.layers.Conv1D(64, 1, padding='same', activation='relu')(x)
  x = tf.keras.layers.BatchNormalization()(x)
  x = tf.keras.layers.Add()([x, shortcut])

  x = tf.keras.layers.Dropout(0.5)(x)

  x = tf.keras.layers.Flatten()(x)
  x = tf.keras.layers.Dropout(0.5)(x)
  x = tf.keras.layers.Dense(48, activation='relu')(x)
  x = tf.keras.layers.BatchNormalization()(x)

  outputs = tf.keras.layers.Dense(3, activation='softmax')(x)

  model = tf.keras.Model(inputs=inputs, outputs=outputs)

  model.compile(loss='categorical_crossentropy', optimizer=opt, metrics=['accuracy'])

  return model

model = getModel4()
model.summary()
# Out:
# Model: "model_11"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_12 (InputLayer)          [(None, 1500, 1)]    0           []
#
#  conv1d_155 (Conv1D)            (None, 1500, 32)     512         ['input_12[0][0]']
#
#  batch_normalization_172 (Batch  (None, 1500, 32)    128         ['conv1d_155[0][0]']
#  Normalization)
#
#  max_pooling1d_44 (MaxPooling1D  (None, 300, 32)     0           ['batch_normalization_172[0][0]']
#  )
#
#  dropout_70 (Dropout)           (None, 300, 32)      0           ['max_pooling1d_44[0][0]']
#
#  conv1d_157 (Conv1D)            (None, 300, 48)      1584        ['dropout_70[0][0]']
#
#  batch_normalization_174 (Batch  (None, 300, 48)     192         ['conv1d_157[0][0]']
#  Normalization)
#
#  conv1d_158 (Conv1D)            (None, 300, 48)      11568       ['batch_normalization_174[0][0]']
#
#  batch_normalization_175 (Batch  (None, 300, 48)     192         ['conv1d_158[0][0]']
#  Normalization)
#
#  conv1d_159 (Conv1D)            (None, 300, 40)      1960        ['batch_normalization_175[0][0]']
#
#  conv1d_156 (Conv1D)            (None, 300, 40)      1320        ['dropout_70[0][0]']
#
#  batch_normalization_176 (Batch  (None, 300, 40)     160         ['conv1d_159[0][0]']
#  Normalization)
#
#  batch_normalization_173 (Batch  (None, 300, 40)     160         ['conv1d_156[0][0]']
#  Normalization)
#
#  add_39 (Add)                   (None, 300, 40)      0           ['batch_normalization_176[0][0]',
#                                                                   'batch_normalization_173[0][0]']
#
#  max_pooling1d_45 (MaxPooling1D  (None, 100, 40)     0           ['add_39[0][0]']
#  )
#
#  dropout_71 (Dropout)           (None, 100, 40)      0           ['max_pooling1d_45[0][0]']
#
#  conv1d_161 (Conv1D)            (None, 100, 64)      2624        ['dropout_71[0][0]']
#
#  batch_normalization_178 (Batch  (None, 100, 64)     256         ['conv1d_161[0][0]']
#  Normalization)
#
#  conv1d_162 (Conv1D)            (None, 100, 64)      20544       ['batch_normalization_178[0][0]']
#
#  batch_normalization_179 (Batch  (None, 100, 64)     256         ['conv1d_162[0][0]']
#  Normalization)
#
#  conv1d_163 (Conv1D)            (None, 100, 48)      3120        ['batch_normalization_179[0][0]']
#
#  conv1d_160 (Conv1D)            (None, 100, 48)      1968        ['dropout_71[0][0]']
#
#  batch_normalization_180 (Batch  (None, 100, 48)     192         ['conv1d_163[0][0]']
#  Normalization)
#
#  batch_normalization_177 (Batch  (None, 100, 48)     192         ['conv1d_160[0][0]']
#  Normalization)
#
#  add_40 (Add)                   (None, 100, 48)      0           ['batch_normalization_180[0][0]',
#                                                                   'batch_normalization_177[0][0]']
#
#  max_pooling1d_46 (MaxPooling1D  (None, 33, 48)      0           ['add_40[0][0]']
#  )
#
#  dropout_72 (Dropout)           (None, 33, 48)       0           ['max_pooling1d_46[0][0]']
#
#  conv1d_165 (Conv1D)            (None, 33, 74)       3626        ['dropout_72[0][0]']
#
#  batch_normalization_182 (Batch  (None, 33, 74)      296         ['conv1d_165[0][0]']
#  Normalization)
#
#  conv1d_166 (Conv1D)            (None, 33, 74)       16502       ['batch_normalization_182[0][0]']
#
#  batch_normalization_183 (Batch  (None, 33, 74)      296         ['conv1d_166[0][0]']
#  Normalization)
#
#  conv1d_167 (Conv1D)            (None, 33, 56)       4200        ['batch_normalization_183[0][0]']
#
#  conv1d_164 (Conv1D)            (None, 33, 56)       2744        ['dropout_72[0][0]']
#
#  batch_normalization_184 (Batch  (None, 33, 56)      224         ['conv1d_167[0][0]']
#  Normalization)
#
#  batch_normalization_181 (Batch  (None, 33, 56)      224         ['conv1d_164[0][0]']
#  Normalization)
#
#  add_41 (Add)                   (None, 33, 56)       0           ['batch_normalization_184[0][0]',
#                                                                   'batch_normalization_181[0][0]']
#
#  max_pooling1d_47 (MaxPooling1D  (None, 11, 56)      0           ['add_41[0][0]']
#  )
#
#  dropout_73 (Dropout)           (None, 11, 56)       0           ['max_pooling1d_47[0][0]']
#
#  conv1d_169 (Conv1D)            (None, 11, 96)       5472        ['dropout_73[0][0]']
#
#  batch_normalization_186 (Batch  (None, 11, 96)      384         ['conv1d_169[0][0]']
#  Normalization)
#
#  conv1d_170 (Conv1D)            (None, 11, 96)       27744       ['batch_normalization_186[0][0]']
#
#  batch_normalization_187 (Batch  (None, 11, 96)      384         ['conv1d_170[0][0]']
#  Normalization)
#
#  conv1d_171 (Conv1D)            (None, 11, 64)       6208        ['batch_normalization_187[0][0]']
#
#  conv1d_168 (Conv1D)            (None, 11, 64)       3648        ['dropout_73[0][0]']
#
#  batch_normalization_188 (Batch  (None, 11, 64)      256         ['conv1d_171[0][0]']
#  Normalization)
#
#  batch_normalization_185 (Batch  (None, 11, 64)      256         ['conv1d_168[0][0]']
#  Normalization)
#
#  add_42 (Add)                   (None, 11, 64)       0           ['batch_normalization_188[0][0]',
#                                                                   'batch_normalization_185[0][0]']
#
#  dropout_74 (Dropout)           (None, 11, 64)       0           ['add_42[0][0]']
#
#  flatten_13 (Flatten)           (None, 704)          0           ['dropout_74[0][0]']
#
#  dropout_75 (Dropout)           (None, 704)          0           ['flatten_13[0][0]']
#
#  dense_30 (Dense)               (None, 48)           33840       ['dropout_75[0][0]']
#
#  batch_normalization_189 (Batch  (None, 48)          192         ['dense_30[0][0]']
#  Normalization)
#
#  dense_31 (Dense)               (None, 3)            147         ['batch_normalization_189[0][0]']
#
# ==================================================================================================
# Total params: 153,571
# Trainable params: 151,451
# Non-trainable params: 2,120
# __________________________________________________________________________________________________

# %%
# IdentityResNet4x2
#  params
def getModel5():
  opt = tf.keras.optimizers.Adam()
  inputs = tf.keras.Input(shape=(1500, 1))

  x = tf.keras.layers.Conv1D(64, 15, padding='same', activation='relu')(inputs)
  x = tf.keras.layers.BatchNormalization()(x)
  x = tf.keras.layers.MaxPooling1D(5)(x)
  x = tf.keras.layers.Dropout(0.5)(x)

  # Residual block 1
  shortcut = x

  x = tf.keras.layers.Conv1D(64, 7, padding='same', activation='relu')(x)
  x = tf.keras.layers.BatchNormalization()(x)
  x = tf.keras.layers.Conv1D(64, 7, padding='same', activation='relu')(x)
  x = tf.keras.layers.BatchNormalization()(x)
  x = tf.keras.layers.Add()([x, shortcut])

  x = tf.keras.layers.MaxPooling1D(3)(x)
  x = tf.keras.layers.Dropout(0.5)(x)

  # Residual block 2
  shortcut = x

  x = tf.keras.layers.Conv1D(64, 5, padding='same', activation='relu')(x)
  x = tf.keras.layers.BatchNormalization()(x)
  x = tf.keras.layers.Conv1D(64, 5, padding='same', activation='relu')(x)
  x = tf.keras.layers.BatchNormalization()(x)
  x = tf.keras.layers.Add()([x, shortcut])

  x = tf.keras.layers.MaxPooling1D(3)(x)
  x = tf.keras.layers.Dropout(0.5)(x)

  # Residual block 3
  shortcut = x

  x = tf.keras.layers.Conv1D(64, 5, padding='same', activation='relu')(x)
  x = tf.keras.layers.BatchNormalization()(x)
  x = tf.keras.layers.Conv1D(64, 5, padding='same', activation='relu')(x)
  x = tf.keras.layers.BatchNormalization()(x)
  x = tf.keras.layers.Add()([x, shortcut])

  x = tf.keras.layers.MaxPooling1D(3)(x)
  x = tf.keras.layers.Dropout(0.5)(x)

  # Residual block 4
  shortcut = x

  x = tf.keras.layers.Conv1D(64, 3, padding='same', activation='relu')(x)
  x = tf.keras.layers.BatchNormalization()(x)
  x = tf.keras.layers.Conv1D(64, 3, padding='same', activation='relu')(x)
  x = tf.keras.layers.BatchNormalization()(x)
  x = tf.keras.layers.Add()([x, shortcut])

  x = tf.keras.layers.Dropout(0.5)(x)

  x = tf.keras.layers.Flatten()(x)
  x = tf.keras.layers.Dropout(0.5)(x)
  x = tf.keras.layers.Dense(48, activation='relu')(x)
  x = tf.keras.layers.BatchNormalization()(x)

  outputs = tf.keras.layers.Dense(3, activation='softmax')(x)

  model = tf.keras.Model(inputs=inputs, outputs=outputs)

  model.compile(loss='categorical_crossentropy', optimizer=opt, metrics=['accuracy'])

  return model

model = getModel5()
model.summary()
# Out:
# Model: "model_2"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_3 (InputLayer)           [(None, 1500, 1)]    0           []
#
#  conv1d_18 (Conv1D)             (None, 1500, 64)     1024        ['input_3[0][0]']
#
#  batch_normalization_20 (BatchN  (None, 1500, 64)    256         ['conv1d_18[0][0]']
#  ormalization)
#
#  max_pooling1d_8 (MaxPooling1D)  (None, 300, 64)     0           ['batch_normalization_20[0][0]']
#
#  dropout_12 (Dropout)           (None, 300, 64)      0           ['max_pooling1d_8[0][0]']
#
#  conv1d_19 (Conv1D)             (None, 300, 64)      28736       ['dropout_12[0][0]']
#
#  batch_normalization_21 (BatchN  (None, 300, 64)     256         ['conv1d_19[0][0]']
#  ormalization)
#
#  conv1d_20 (Conv1D)             (None, 300, 64)      28736       ['batch_normalization_21[0][0]']
#
#  batch_normalization_22 (BatchN  (None, 300, 64)     256         ['conv1d_20[0][0]']
#  ormalization)
#
#  add_8 (Add)                    (None, 300, 64)      0           ['batch_normalization_22[0][0]',
#                                                                   'dropout_12[0][0]']
#
#  max_pooling1d_9 (MaxPooling1D)  (None, 100, 64)     0           ['add_8[0][0]']
#
#  dropout_13 (Dropout)           (None, 100, 64)      0           ['max_pooling1d_9[0][0]']
#
#  conv1d_21 (Conv1D)             (None, 100, 64)      20544       ['dropout_13[0][0]']
#
#  batch_normalization_23 (BatchN  (None, 100, 64)     256         ['conv1d_21[0][0]']
#  ormalization)
#
#  conv1d_22 (Conv1D)             (None, 100, 64)      20544       ['batch_normalization_23[0][0]']
#
#  batch_normalization_24 (BatchN  (None, 100, 64)     256         ['conv1d_22[0][0]']
#  ormalization)
#
#  add_9 (Add)                    (None, 100, 64)      0           ['batch_normalization_24[0][0]',
#                                                                   'dropout_13[0][0]']
#
#  max_pooling1d_10 (MaxPooling1D  (None, 33, 64)      0           ['add_9[0][0]']
#  )
#
#  dropout_14 (Dropout)           (None, 33, 64)       0           ['max_pooling1d_10[0][0]']
#
#  conv1d_23 (Conv1D)             (None, 33, 64)       20544       ['dropout_14[0][0]']
#
#  batch_normalization_25 (BatchN  (None, 33, 64)      256         ['conv1d_23[0][0]']
#  ormalization)
#
#  conv1d_24 (Conv1D)             (None, 33, 64)       20544       ['batch_normalization_25[0][0]']
#
#  batch_normalization_26 (BatchN  (None, 33, 64)      256         ['conv1d_24[0][0]']
#  ormalization)
#
#  add_10 (Add)                   (None, 33, 64)       0           ['batch_normalization_26[0][0]',
#                                                                   'dropout_14[0][0]']
#
#  max_pooling1d_11 (MaxPooling1D  (None, 11, 64)      0           ['add_10[0][0]']
#  )
#
#  dropout_15 (Dropout)           (None, 11, 64)       0           ['max_pooling1d_11[0][0]']
#
#  conv1d_25 (Conv1D)             (None, 11, 64)       12352       ['dropout_15[0][0]']
#
#  batch_normalization_27 (BatchN  (None, 11, 64)      256         ['conv1d_25[0][0]']
#  ormalization)
#
#  conv1d_26 (Conv1D)             (None, 11, 64)       12352       ['batch_normalization_27[0][0]']
#
#  batch_normalization_28 (BatchN  (None, 11, 64)      256         ['conv1d_26[0][0]']
#  ormalization)
#
#  add_11 (Add)                   (None, 11, 64)       0           ['batch_normalization_28[0][0]',
#                                                                   'dropout_15[0][0]']
#
#  dropout_16 (Dropout)           (None, 11, 64)       0           ['add_11[0][0]']
#
#  flatten_2 (Flatten)            (None, 704)          0           ['dropout_16[0][0]']
#
#  dropout_17 (Dropout)           (None, 704)          0           ['flatten_2[0][0]']
#
#  dense_4 (Dense)                (None, 48)           33840       ['dropout_17[0][0]']
#
#  batch_normalization_29 (BatchN  (None, 48)          192         ['dense_4[0][0]']
#  ormalization)
#
#  dense_5 (Dense)                (None, 3)            147         ['batch_normalization_29[0][0]']
#
# ==================================================================================================
# Total params: 201,859
# Trainable params: 200,611
# Non-trainable params: 1,248
# __________________________________________________________________________________________________
